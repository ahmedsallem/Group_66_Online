# %%
import numpy as np
import pandas as pd

# %%
# CarPrice_Assignment.csv
# EDA
# head
# tail
# info
# describe   >>> cat_cols   and num_cols 
# columns
# index
# dtypes

# %%
df = pd.read_csv("CarPrice_Assignment.csv")

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  fuelsystem  \
# 0  convertible        rwd          front       88.6  ...        mpfi
# 1  convertible        rwd          front       88.6  ...        mpfi
# 2    hatchback        rwd          front       94.5  ...        mpfi
# 3        sedan        fwd          front       99.8  ...        mpfi
# 4        sedan        4wd          front       99.4  ...        mpfi
#
#    boreratio  stroke  compressionratio horsepower peakrpm  citympg highwaympg  \
# ...

# %%
df.tail()
# Out:
#      car_ID  symboling          CarName fueltype aspiration doornumber  \
# 200     201         -1  volvo 145e (sw)      gas        std       four
# 201     202         -1      volvo 144ea      gas      turbo       four
# 202     203         -1      volvo 244dl      gas        std       four
# 203     204         -1        volvo 246   diesel      turbo       four
# 204     205         -1      volvo 264gl      gas      turbo       four
#
#     carbody drivewheel enginelocation  wheelbase  ...  fuelsystem  boreratio  \
# 200   sedan        rwd          front      109.1  ...        mpfi       3.78
# 201   sedan        rwd          front      109.1  ...        mpfi       3.78
# 202   sedan        rwd          front      109.1  ...        mpfi       3.58
# 203   sedan        rwd          front      109.1  ...         idi       3.01
# 204   sedan        rwd          front      109.1  ...        mpfi       3.78
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
df.isna().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# highwaympg.1        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
df.describe(include="object")
# Out:
#               CarName fueltype aspiration doornumber carbody drivewheel  \
# count             205      205        205        205     205        205
# unique            147        2          2          2       5          3
# top     toyota corona      gas        std       four   sedan        fwd
# freq                6      185        168        115      96        120
#
#        enginelocation enginetype cylindernumber fuelsystem
# count             205        205            205        205
# unique              2          7              7          8
# top             front        ohc           four       mpfi
# freq              202        148            159         94

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  fuelsystem  \
# 0  convertible        rwd          front       88.6  ...        mpfi
# 1  convertible        rwd          front       88.6  ...        mpfi
# 2    hatchback        rwd          front       94.5  ...        mpfi
# 3        sedan        fwd          front       99.8  ...        mpfi
# 4        sedan        4wd          front       99.4  ...        mpfi
#
#    boreratio  stroke  compressionratio horsepower peakrpm  citympg highwaympg  \
# ...

# %%
df.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price', 'highwaympg.1'],
#       dtype='object')

# %%
df["doornumber"].value_counts()
# Out:
# four    115
# two      90
# Name: doornumber, dtype: int64

# %%
d = {"color":["red", "green" , "blue" , "red" , "green" , "blue" , "blue" , "black" ]}
c = pd.DataFrame(d)
c
# Out:
#    color
# 0    red
# 1  green
# 2   blue
# 3    red
# 4  green
# 5   blue
# 6   blue
# 7  black

# %%
from sklearn.preprocessing import LabelEncoder , OneHotEncoder

# %%
label = LabelEncoder()

# %%
label.fit(c["color"])
# Out:
# LabelEncoder()

# %%
c["label"]=label.transform(c["color"])

# %%
c
# Out:
#    color  label
# 0    red      3
# 1  green      2
# 2   blue      1
# 3    red      3
# 4  green      2
# 5   blue      1
# 6   blue      1
# 7  black      0

# %%
c["rep"]=c["color"].replace({"red":0 , "blue":1 , "green":2 , "black":3})

# %%
c
# Out:
#    color  label  rep
# 0    red      3    0
# 1  green      2    2
# 2   blue      1    1
# 3    red      3    0
# 4  green      2    2
# 5   blue      1    1
# 6   blue      1    1
# 7  black      0    3

# %%
pd.get_dummies(c , columns=["color"])
# Out:
#    label  rep  color_black  color_blue  color_green  color_red
# 0      3    0            0           0            0          1
# 1      2    2            0           0            1          0
# 2      1    1            0           1            0          0
# 3      3    0            0           0            0          1
# 4      2    2            0           0            1          0
# 5      1    1            0           1            0          0
# 6      1    1            0           1            0          0
# 7      0    3            1           0            0          0

# %%
label.inverse_transform([1,2,3])
# Out:
# array(['blue', 'green', 'red'], dtype=object)

# %%
df.select_dtypes("number").corr()["price"]
# Out:
# car_ID             -0.109093
# symboling          -0.079978
# wheelbase           0.577816
# carlength           0.682920
# carwidth            0.759325
# carheight           0.119336
# curbweight          0.835305
# enginesize          0.874145
# boreratio           0.553173
# stroke              0.079443
# compressionratio    0.067984
# horsepower          0.808139
# peakrpm            -0.085267
# citympg            -0.685751
# highwaympg         -0.697599
# price               1.000000
# highwaympg.1       -0.697599
# Name: price, dtype: float64

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  fuelsystem  \
# 0  convertible        rwd          front       88.6  ...        mpfi
# 1  convertible        rwd          front       88.6  ...        mpfi
# 2    hatchback        rwd          front       94.5  ...        mpfi
# 3        sedan        fwd          front       99.8  ...        mpfi
# 4        sedan        4wd          front       99.4  ...        mpfi
#
#    boreratio  stroke  compressionratio horsepower peakrpm  citympg highwaympg  \
# ...

# %%
df["doornumber"].value_counts()
# Out:
# four    115
# two      90
# Name: doornumber, dtype: int64

# %%
pd.get_dummies(df , columns = ["doornumber"])
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#          carbody drivewheel enginelocation  wheelbase  carlength  ...  stroke  \
# ...

# %%
df["doornumber"] = df["doornumber"].replace({"four":4 , "two":2})

# %%
df.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price', 'highwaympg.1'],
#       dtype='object')

# %%
df["cylindernumber"].value_counts()
# Out:
# four      159
# six        24
# five       11
# eight       5
# two         4
# three       1
# twelve      1
# Name: cylindernumber, dtype: int64

# %%
# pip install word2number

# %%
from word2number import w2n

# %%
w2n.word_to_num("four")
# Out:
# 4

# %%
w2n.word_to_num("five")
# Out:
# 5

# %%
# w2n.word_to_num(3) Error

# %%
w2n.word_to_num('two million twenty three thousand and forty nine')
# Out:
# 2023049

# %%
try:
    df["cylindernumber"] = df["cylindernumber"].map(w2n.word_to_num)   #df["cylindernumber"].apply(w2n.word_to_num) 
except Exception as e :
    print("Error:",e)
# Out:
# Error: Type of input is not string! Please enter a valid number word (eg. 'two million twenty three thousand and forty nine')

# %%
df["cylindernumber"].value_counts()
# Out:
# 4     159
# 6      24
# 5      11
# 8       5
# 2       4
# 3       1
# 12      1
# Name: cylindernumber, dtype: int64

# %%
df["CarName"].describe()
# Out:
# count               205
# unique              147
# top       toyota corona
# freq                  6
# Name: CarName, dtype: object

# %%
df["CarName"].value_counts()
# Out:
# toyota corona           6
# toyota corolla          6
# peugeot 504             6
# subaru dl               4
# mitsubishi mirage g4    3
#                        ..
# mazda glc 4             1
# mazda rx2 coupe         1
# maxda glc deluxe        1
# maxda rx3               1
# volvo 246               1
# Name: CarName, Length: 147, dtype: int64

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration  \
# 0       1          3        alfa-romero giulia      gas        std
# 1       2          3       alfa-romero stelvio      gas        std
# 2       3          1  alfa-romero Quadrifoglio      gas        std
# 3       4          2               audi 100 ls      gas        std
# 4       5          2                audi 100ls      gas        std
#
#    doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# 0           2  convertible        rwd          front       88.6  ...
# 1           2  convertible        rwd          front       88.6  ...
# 2           2    hatchback        rwd          front       94.5  ...
# 3           4        sedan        fwd          front       99.8  ...
# 4           4        sedan        4wd          front       99.4  ...
#
#    fuelsystem  boreratio  stroke  compressionratio horsepower  peakrpm  \
# 0        mpfi       3.47    2.68               9.0        111     5000
# ...

# %%
df["CarName"].apply(lambda x : x.split()[0])
# Out:
# 0      alfa-romero
# 1      alfa-romero
# 2      alfa-romero
# 3             audi
# 4             audi
#           ...
# 200          volvo
# 201          volvo
# 202          volvo
# 203          volvo
# 204          volvo
# Name: CarName, Length: 205, dtype: object

# %%
df["CarName"] = df["CarName"].str.split(expand = True)[0]

# %%
df["CarName"].value_counts()
# Out:
# toyota         31
# nissan         17
# mazda          15
# honda          13
# mitsubishi     13
# subaru         12
# peugeot        11
# volvo          11
# volkswagen      9
# dodge           9
# buick           8
# bmw             8
# audi            7
# plymouth        7
# saab            6
# isuzu           4
# porsche         4
# alfa-romero     3
# chevrolet       3
# jaguar          3
# vw              2
# maxda           2
# renault         2
# toyouta         1
# vokswagen       1
# Nissan          1
# mercury         1
# porcshce        1
# Name: CarName, dtype: int64

# %%
df["CarName"] = df["CarName"].replace({"toyouta":"toyota" , "maxda":"mazda"})

# %%
df["CarName"].value_counts()
# Out:
# toyota         32
# nissan         17
# mazda          17
# honda          13
# mitsubishi     13
# subaru         12
# peugeot        11
# volvo          11
# volkswagen      9
# dodge           9
# bmw             8
# buick           8
# audi            7
# plymouth        7
# saab            6
# isuzu           4
# porsche         4
# jaguar          3
# chevrolet       3
# alfa-romero     3
# renault         2
# vw              2
# Nissan          1
# vokswagen       1
# mercury         1
# porcshce        1
# Name: CarName, dtype: int64

# %%
df["CarName"] = df["CarName"].str.title()

# %%
df["CarName"].value_counts()
# Out:
# Toyota         32
# Nissan         18
# Mazda          17
# Honda          13
# Mitsubishi     13
# Subaru         12
# Peugeot        11
# Volvo          11
# Volkswagen      9
# Dodge           9
# Buick           8
# Bmw             8
# Audi            7
# Plymouth        7
# Saab            6
# Isuzu           4
# Porsche         4
# Jaguar          3
# Chevrolet       3
# Alfa-Romero     3
# Renault         2
# Vw              2
# Vokswagen       1
# Mercury         1
# Porcshce        1
# Name: CarName, dtype: int64

# %%
df["CarName"].describe()
# Out:
# count        205
# unique        25
# top       Toyota
# freq          32
# Name: CarName, dtype: object

# %%
df.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price', 'highwaympg.1'],
#       dtype='object')

# %%
df.groupby("carbody")["price"].agg(["min" ,"max"] )
# Out:
#                  min      max
# carbody
# convertible  11595.0  37028.0
# hardtop       8249.0  45400.0
# hatchback     5118.0  31400.5
# sedan         5499.0  41315.0
# wagon         6918.0  28248.0

# %%
df.groupby("CarName")["price"].agg(["min" ,"max"] ).sort_values(by = "min")
# Out:
#                  min      max
# CarName
# Subaru        5118.0  11694.0
# Chevrolet     5151.0   6575.0
# Mazda         5195.0  18344.0
# Toyota        5348.0  17669.0
# Mitsubishi    5389.0  14869.0
# Honda         5399.0  12945.0
# Nissan        5499.0  19699.0
# Dodge         5572.0  12964.0
# Plymouth      5572.0  12764.0
# Isuzu         6785.0  11048.0
# Vokswagen     7775.0   7775.0
# Volkswagen    7975.0  13845.0
# Renault       9295.0   9895.0
# Vw            9980.0  11595.0
# Saab         11850.0  18620.0
# Peugeot      11900.0  18150.0
# Volvo        12940.0  22625.0
# Alfa-Romero  13495.0  16500.0
# Audi         13950.0  23875.0
# Bmw          16430.0  41315.0
# Mercury      16503.0  16503.0
# Porsche      22018.0  37028.0
# Buick        25552.0  45400.0
# Jaguar       32250.0  36000.0
# Porcshce     32528.0  32528.0

# %%
df.groupby("enginelocation")["price"].agg(["min" ,"max" , "count"] )
# Out:
#                     min      max  count
# enginelocation
# front            5118.0  45400.0    202
# rear            32528.0  37028.0      3

# %%
df[df["enginelocation"] == "rear"]
# Out:
#      car_ID  symboling   CarName fueltype aspiration  doornumber      carbody  \
# 126     127          3  Porcshce      gas        std           2      hardtop
# 127     128          3   Porsche      gas        std           2      hardtop
# 128     129          3   Porsche      gas        std           2  convertible
#
#     drivewheel enginelocation  wheelbase  ...  fuelsystem  boreratio  stroke  \
# 126        rwd           rear       89.5  ...        mpfi       3.74     2.9
# 127        rwd           rear       89.5  ...        mpfi       3.74     2.9
# 128        rwd           rear       89.5  ...        mpfi       3.74     2.9
#
#      compressionratio horsepower  peakrpm  citympg highwaympg    price  \
# 126               9.5        207     5900       17         25  32528.0
# 127               9.5        207     5900       17         25  34028.0
# 128               9.5        207     5900       17         25  37028.0
#
#      highwaympg.1
# 126            25
# ...

# %%
v = df.select_dtypes("number").corr()["price"].abs().sort_values()
v
# Out:
# doornumber          0.031835
# compressionratio    0.067984
# stroke              0.079443
# symboling           0.079978
# peakrpm             0.085267
# car_ID              0.109093
# carheight           0.119336
# boreratio           0.553173
# wheelbase           0.577816
# carlength           0.682920
# citympg             0.685751
# highwaympg.1        0.697599
# highwaympg          0.697599
# cylindernumber      0.718305
# carwidth            0.759325
# horsepower          0.808139
# curbweight          0.835305
# enginesize          0.874145
# price               1.000000
# Name: price, dtype: float64

# %%
v[v["price"]>= .5 ]
# Out:
#              index     price
# 7        boreratio  0.553173
# 8        wheelbase  0.577816
# 9        carlength  0.682920
# 10         citympg  0.685751
# 11    highwaympg.1  0.697599
# 12      highwaympg  0.697599
# 13  cylindernumber  0.718305
# 14        carwidth  0.759325
# 15      horsepower  0.808139
# 16      curbweight  0.835305
# 17      enginesize  0.874145
# 18           price  1.000000

# %%
# v = df.select_dtypes("number").corr()["price"].abs().sort_values() >= 0.5

# %%
# col = []
# for i , value  in enumerate(v) :
#     if value >= .5:
#         col.append(i)

# %%
# col

# %%
try:
    df.drop(columns=["carheight", "car_ID" , "peakrpm" , "symboling", "stroke" , "compressionratio" , "doornumber"], 
        axis = 1  , inplace=True)   # axis = 1 >> colsssssss
except Exception as e :
    print("Error:" , e)
# Out:
# Error: "['carheight', 'car_ID', 'peakrpm', 'symboling', 'stroke', 'compressionratio', 'doornumber'] not found in axis"

# %%
df.drop(4)  # axis = 0 >> rowsssssssss
# Out:
#          CarName fueltype aspiration      carbody drivewheel enginelocation  \
# 0    Alfa-Romero      gas        std  convertible        rwd          front
# 1    Alfa-Romero      gas        std  convertible        rwd          front
# 2    Alfa-Romero      gas        std    hatchback        rwd          front
# 3           Audi      gas        std        sedan        fwd          front
# 5           Audi      gas        std        sedan        fwd          front
# ..           ...      ...        ...          ...        ...            ...
# 200        Volvo      gas        std        sedan        rwd          front
# 201        Volvo      gas      turbo        sedan        rwd          front
# 202        Volvo      gas        std        sedan        rwd          front
# 203        Volvo   diesel      turbo        sedan        rwd          front
# 204        Volvo      gas      turbo        sedan        rwd          front
#
# ...

# %%
x = df.drop("price" , axis = 1 )    # هات كل الكولومز ما عدا كولوم ال price

# %%
y = df["price"]

# %%
x.shape
# Out:
# (205, 19)

# %%
y.shape
# Out:
# (205,)

# %%
from sklearn.model_selection import train_test_split

# %%
help(train_test_split)
# Out:
# Help on function train_test_split in module sklearn.model_selection._split:
#
# train_test_split(*arrays, test_size=None, train_size=None, random_state=None, shuffle=True, stratify=None)
#     Split arrays or matrices into random train and test subsets.
#
#     Quick utility that wraps input validation,
#     ``next(ShuffleSplit().split(X, y))``, and application to input data
#     into a single call for splitting (and optionally subsampling) data into a
#     one-liner.
#
#     Read more in the :ref:`User Guide <cross_validation>`.
#
#     Parameters
#     ----------
#     *arrays : sequence of indexables with same length / shape[0]
#         Allowed inputs are lists, numpy arrays, scipy-sparse
#         matrices or pandas dataframes.
#
#     test_size : float or int, default=None
#         If float, should be between 0.0 and 1.0 and represent the proportion
#         of the dataset to include in the test split. If int, represents the
# ...

# %%
x_train , x_test , y_train , y_test =train_test_split(x , y , train_size=.5)

# %%
# x.shape
x_train.shape
# Out:
# (102, 19)

# %%
y_train.shape
# Out:
# (102,)

# %%
x_test.shape
# Out:
# (103, 19)

# %%
y_test.shape
# Out:
# (103,)
